# %%
import duckdb as ddb
import pandas as pd

# %%
sql_query = '''
show tables; 
'''

with ddb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#                               name
# 0   bronze_parking_violation_codes
# 1        bronze_parking_violations
# 2                      first_model
# 3              gold_ticket_metrics
# 4             gold_vehicle_metrics
# 5          parking_violation_codes
# 6          parking_violations_2025
# 7                        ref_model
# 8   silver_parking_violation_codes
# 9        silver_parking_violations
# 10        silver_violation_tickets
# 11       silver_violation_vehicles

# %%
sql_query_import_1 = """
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT * 
FROM read_csv_auto(
    'data/DOF_Parking_Violation_Codes_20260603.csv',
    normalize_names=True
)
"""

# %%
sql_query_import_2 = """
CREATE OR REPLACE TABLE parking_violations_2025 AS
SELECT * 
FROM read_csv_auto(
    'data/sample_parking_violations_2025.csv',
    normalize_names=True
)
"""

# %%
with ddb.connect("data/nyc_parking_violations.db") as con:
    con.sql(sql_query_import_1)
    con.sql(sql_query_import_2)

# %%
sql_query = """
SELECT * FROM parking_violation_codes
LIMIT 5;
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#    code                      definition  manhattan_96th_st_below  \
# 0     1   FAILURE TO DISPLAY BUS PERMIT                      515
# 1     2  NO OPERATOR NAM/ADD/PH DISPLAY                      515
# 2     3  UNAUTHORIZED PASSENGER PICK-UP                      515
# 3     4  BUS PARKING IN LOWER MANHATTAN                      115
# 4     5              BUS LANE VIOLATION                      250
#
#    all_other_areas
# 0              515
# 1              515
# 2              515
# 3              115
# 4              250

# %%
sql_query = """
show tables; 
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#                               name
# 0   bronze_parking_violation_codes
# 1        bronze_parking_violations
# 2                      first_model
# 3              gold_ticket_metrics
# 4             gold_vehicle_metrics
# 5          parking_violation_codes
# 6          parking_violations_2025
# 7                        ref_model
# 8   silver_parking_violation_codes
# 9        silver_parking_violations
# 10        silver_violation_tickets
# 11       silver_violation_vehicles

# %%
sql_query = """
SELECT * FROM ref_model;
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#    count_star()
# 0            97

# %%
sql_query = """
SELECT * FROM bronze_parking_violation_codes
LIMIT 3;
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code                      definition  manhattan_96th_st_below  \
# 0               1   FAILURE TO DISPLAY BUS PERMIT                      515
# 1               2  NO OPERATOR NAM/ADD/PH DISPLAY                      515
# 2               3  UNAUTHORIZED PASSENGER PICK-UP                      515
#
#    all_other_areas
# 0              515
# 1              515
# 2              515

# %%
sql_query = """
SELECT * FROM bronze_parking_violations
LIMIT 3;
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#    summons_number registration_state plate_type issue_date  violation_code  \
# 0      4906674367                 TX        PAS 2024-07-08            36.0
# 1      4906075502                 NY        PAS 2024-07-09            36.0
# 2      4907839261                 NJ        PAS 2024-07-17            36.0
#
#   vehicle_body_type vehicle_make issuing_agency  vehicle_expiration_date  \
# 0                4D        DODGE              V                      0.0
# 1              4DSD        CHEVR              V                      0.0
# 2                UT         AUDI              V                      0.0
#
#    violation_location  violation_precinct  issuer_precinct  issuer_code  \
# 0                 NaN                 0.0              0.0          0.0
# 1                 NaN                 0.0              0.0          0.0
# 2                 NaN                 0.0              0.0          0.0
#
#   issuer_command issuer_squad violation_time violation_county  \
# 0           None         None          0416A               QN
# 1           None         None          0424P               BX
# 2           None         None          0625P               BX
#
#    violation_legal_code vehicle_color  vehicle_year
# 0                  True           NaN        2013.0
# 1                  True            GY        2018.0
# 2                  True           NaN        2022.0

# %%
sql_query = """
SELECT * FROM silver_violation_tickets
LIMIT 3; 
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#    summons_number issue_date  violation_code  is_manhattan_96th_st_below  \
# 0      4906674367 2024-07-08            36.0                       False
# 1      4906075502 2024-07-09            36.0                       False
# 2      4907839261 2024-07-17            36.0                       False
#
#   issuing_agency  violation_location  issuer_precinct  issuer_code  \
# 0              V                 NaN              0.0          0.0
# 1              V                 NaN              0.0          0.0
# 2              V                 NaN              0.0          0.0
#
#   issuer_command issuer_squad violation_time violation_county  \
# 0           None         None          0416A               QN
# 1           None         None          0424P               BX
# 2           None         None          0625P               BX
#
#    violation_legal_code  fee_usd
# 0                  True      NaN
# 1                  True      NaN
# 2                  True      NaN

# %%
sql_query = """
SELECT * FROM gold_ticket_metrics
LIMIT 3; 
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code  ticket_count  total_revenue_usd
# 0             5.0           424            31750.0
# 1            36.0          3992            14400.0
# 2            12.0           135             7000.0

# %%
sql_query = """
SELECT * FROM gold_vehicle_metrics
LIMIT 3; 
"""

with ddb.connect("data/nyc_parking_violations.db") as con:
    display(con.sql(sql_query).df())
# Out:
#   registration_state  ticket_count
# 0                 NJ          1042
# 1                 PA           400
# 2                 FL           225
